# %% [markdown]
# # Maven Analytics Challenge May 2024
# ## UK National Rail
#
# https://mavenanalytics.io/challenges/maven-rail-challenge/08941141-d23f-4cc9-93a3-4c25ed06e1c3
#
# For the Maven Rail Challenge, you'll play the role of a BI Developer for National Rail, a company that provides business services to passenger train operators in England, Scotland, and Wales.
#
# You've been asked by your manager to create an exploratory dashboard that helps them:
#
# - Identify the most popular routes
# - Determine peak travel times
# - Analyze revenue from different ticket types & classes
# - Diagnose on-time performance and contributing factors

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import the two raw data files into dataframes

# %%
# read the railway.csv data from the data folder into a dataframe called df_railway
df_railway = pd.read_csv('../data/railway.csv')
df_railway.head()
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
#
#   Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0    Contactless    Adult     Standard     Advance     43
# 1    Credit Card    Adult     Standard     Advance     23
# 2    Credit Card      NaN     Standard     Advance      3
# 3    Credit Card      NaN     Standard     Advance     13
# 4    Contactless      NaN     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      2024-01-01
# 1     London Kings Cross                   York      2024-01-01
# 2  Liverpool Lime Street  Manchester Piccadilly      2024-01-02
# 3      London Paddington                Reading      2024-01-01
# 4  Liverpool Lime Street          London Euston      2024-01-01
#
#   Departure Time Arrival Time Actual Arrival Time Journey Status  \
# 0       11:00:00     13:30:00            13:30:00        On Time
# 1       09:45:00     11:35:00            11:40:00        Delayed
# 2       18:15:00     18:45:00            18:45:00        On Time
# 3       21:30:00     22:30:00            22:30:00        On Time
# 4       16:45:00     19:00:00            19:00:00        On Time
#
#   Reason for Delay Refund Request
# 0              NaN             No
# 1   Signal Failure             No
# 2              NaN             No
# 3              NaN             No
# 4              NaN             No

# %% [markdown]
# Inspect the data dictionary

# %%
# import railway_data_dictionary.csv from the data folder into a dataframe called df_data_dict
df_data_dict = pd.read_csv('../data/railway_data_dictionary.csv')

# display the full width of the dataframe
pd.set_option('display.max_colwidth', None)

# display the dataframe
df_data_dict
# Out:
#                   Field  \
# 0        Transaction ID
# 1      Date of Purchase
# 2      Time of Purchase
# 3         Purchase Type
# 4        Payment Method
# 5              Railcard
# 6          Ticket Class
# 7           Ticket Type
# 8                 Price
# 9     Departure Station
# 10  Arrival Destination
# 11      Date of Journey
# 12       Departure Time
# 13         Arrival Time
# 14  Actual Arrival Time
# 15       Journey Status
# 16     Reason for Delay
# 17       Refund Request
#
#                                                                                                                                                                                                                                                                                                                   Description
# 0                                                                                                                                                                                                                                                                   Unique identifier for an individual train ticket purchase
# 1                                                                                                                                                                                                                                                                                               Date the ticket was purchased
# 2                                                                                                                                                                                                                                                                                               Time the ticket was purchased
# 3                                                                                                                                                                                                                                                      Whether the ticket was purchased online or directly at a train station
# 4                                                                                                                                                                                                                                         Payment method used to purchase the ticket (Contactles, Credit Card, or Debit Card)
# 5                                                                                                                                                                        Whether the passenger is a National Railcard holder (Adult, Senior, or Disabled) or not (None). Railcard holders get 1/3 off their ticket purchases.
# 6                                                                                                                                                                                                                                                                               Seat class for the ticket (Standard or First)
# 7   When you bought or can use the ticket. Advance tickets are 1/2 off and must be purchased at least a day prior to departure. Off-Peak tickets are 1/4 off and must be used outside of peak hours (weekdays between 6-8am and 4-6pm). Anytime tickets are full price and can be bought and used at any time during the day.
# 8                                                                                                                                                                                                                                                                                                    Final cost of the ticket
# 9                                                                                                                                                                                                                                                                                                  Station to board the train
# 10                                                                                                                                                                                                                                                                                                  Station to exit the train
# 11                                                                                                                                                                                                                                                                                                    Date the train departed
# 12                                                                                                                                                                                                                                                                                                    Time the train departed
# 13                                                                                                                                                                                                                              Time the train was scheduled to arrive at its destination (can be on the day after departure)
# 14                                                                                                                                                                                                                                              Time the train arrived at its destination (can be on the day after departure)
# 15                                                                                                                                                                                                                                                                       Whether the train was on time, delayed, or cancelled
# 16                                                                                                                                                                                                                                                                                       Reason for the delay or cancellation
# 17                                                                                                                                                                                                                                                     Whether the passenger requested a refund after a delay or cancellation

# %% [markdown]
# Inspect the incidence of NaNs

# %%
# display the counts of NaN in the dataframe
nan_counts = df_railway.isnull().sum()
nan_counts[nan_counts > 0]
# Out:
# Railcard               20918
# Actual Arrival Time     1880
# Reason for Delay       27481
# dtype: int64

# %%
df_railway['Railcard'].fillna('None').value_counts()
# Out:
# Railcard
# None        20918
# Adult        4846
# Disabled     3089
# Senior       2800
# Name: count, dtype: int64

# %%
# fill the Railcard column with 'None' where there are NaN values
df_railway['Railcard'] = df_railway['Railcard'].fillna('None')
df_railway['Railcard'].value_counts()
# Out:
# Railcard
# None        20918
# Adult        4846
# Disabled     3089
# Senior       2800
# Name: count, dtype: int64

# %%
df_railway['Reason for Delay'].fillna('n/a').value_counts()
# Out:
# Reason for Delay
# n/a                   27481
# Weather                 995
# Technical Issue         707
# Signal Failure          523
# Signal failure          447
# Staffing                410
# Staff Shortage          399
# Weather Conditions      377
# Traffic                 314
# Name: count, dtype: int64

# %%
# fill the Railcard column with 'None' where there are NaN values
df_railway['Reason for Delay'] = df_railway['Reason for Delay'].fillna('Not delayed')
df_railway['Reason for Delay'].value_counts()
# Out:
# Reason for Delay
# Not delayed           27481
# Weather                 995
# Technical Issue         707
# Signal Failure          523
# Signal failure          447
# Staffing                410
# Staff Shortage          399
# Weather Conditions      377
# Traffic                 314
# Name: count, dtype: int64

# %%
# display the counts of NaN in the dataframe
nan_counts = df_railway.isnull().sum()
nan_counts[nan_counts > 0]
# Out:
# Actual Arrival Time    1880
# dtype: int64

# %%
# show a random sample of rows where the Actual Arrival Time is NaN
df_railway[df_railway['Actual Arrival Time'].isnull()].sample(5)
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 18443  f6948b5f-d3d9-4df2-924b       2024-03-11         07:48:17
# 19197  fe523d44-bcff-4e78-b5e9       2024-03-14         03:28:33
# 21965  096d0f88-5fb0-4265-b5bc       2024-03-24         11:55:31
# 7951   ba49cd0d-c9af-4123-b4f3       2024-01-30         07:29:31
# 30829  4cf0a286-c0a5-4ff7-82f9       2024-04-27         11:10:26
#
#       Purchase Type Payment Method Railcard Ticket Class Ticket Type  Price  \
# 18443        Online     Debit Card   Senior     Standard     Advance      8
# 19197        Online    Contactless     None     Standard     Advance      8
# 21965        Online    Credit Card     None     Standard    Off-Peak     10
# 7951         Online    Credit Card     None     Standard     Anytime     35
# 30829       Station    Contactless     None     Standard    Off-Peak     10
#
#        Departure Station    Arrival Destination Date of Journey  \
# 18443  London Paddington                Reading      2024-03-12
# 19197               York                 Durham      2024-03-15
# 21965      London Euston  Birmingham New Street      2024-03-24
# 7951   London Paddington                 Oxford      2024-01-30
# 30829      London Euston  Birmingham New Street      2024-04-27
#
#       Departure Time Arrival Time Actual Arrival Time Journey Status  \
# 18443       06:15:00     07:15:00                 NaN      Cancelled
# 19197       01:45:00     02:35:00                 NaN      Cancelled
# 21965       13:15:00     14:35:00                 NaN      Cancelled
# 7951        07:45:00     09:15:00                 NaN      Cancelled
# 30829       12:30:00     13:50:00                 NaN      Cancelled
#
#       Reason for Delay Refund Request
# 18443  Technical Issue            Yes
# 19197          Weather            Yes
# 21965   Signal failure             No
# 7951           Traffic             No
# 30829   Signal Failure             No

# %%
# show the value counts of Journey Status for rows where Actual Arrival Time is NaN
df_railway[df_railway['Actual Arrival Time'].isnull()]['Journey Status'].value_counts()
# Out:
# Journey Status
# Cancelled    1880
# Name: count, dtype: int64

# %%
# show any rows where the Date of Journey is before the Date of Purchase
df_railway[df_railway['Date of Journey'] < df_railway['Date of Purchase']]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Date of Purchase, Time of Purchase, Purchase Type, Payment Method, Railcard, Ticket Class, Ticket Type, Price, Departure Station, Arrival Destination, Date of Journey, Departure Time, Arrival Time, Actual Arrival Time, Journey Status, Reason for Delay, Refund Request]
# Index: []

# %%
# show any rows where the Departure Station is the same as the Arrival Destination
df_railway[df_railway['Departure Station'] == df_railway['Arrival Destination']]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Date of Purchase, Time of Purchase, Purchase Type, Payment Method, Railcard, Ticket Class, Ticket Type, Price, Departure Station, Arrival Destination, Date of Journey, Departure Time, Arrival Time, Actual Arrival Time, Journey Status, Reason for Delay, Refund Request]
# Index: []

# %%
# create a 'Route' column that combines the Departure Station and Arrival Destination, separated with a dash
df_railway['Route'] = df_railway['Departure Station'] + ' - ' + df_railway['Arrival Destination']
df_railway['Route'].head()
# Out:
# 0        London Paddington - Liverpool Lime Street
# 1                        London Kings Cross - York
# 2    Liverpool Lime Street - Manchester Piccadilly
# 3                      London Paddington - Reading
# 4            Liverpool Lime Street - London Euston
# Name: Route, dtype: object

# %%
# set the notebook to display all rows of the dataframe
pd.set_option('display.max_rows', None)

# produce descriptive statistics of Price for each Route. Show all rows. 
route_prices_stats = df_railway.groupby('Route')['Price'].describe()
route_prices_stats
# Out:
#                                                 count        mean        std  \
# Route
# Birmingham New Street - Coventry                 65.0    4.138462   1.210332
# Birmingham New Street - Edinburgh                16.0   49.875000  25.120709
# Birmingham New Street - Liverpool Lime Street   175.0   10.228571  13.787563
# Birmingham New Street - London Euston           125.0   28.752000  15.520879
# Birmingham New Street - London Kings Cross       17.0   31.470588  23.076280
# Birmingham New Street - London Paddington        32.0   22.437500  16.453135
# Birmingham New Street - London St Pancras       702.0   27.081197  15.793079
# Birmingham New Street - Manchester Piccadilly   224.0   11.191964   5.149228
# Birmingham New Street - Nuneaton                219.0    9.972603   4.271645
# Birmingham New Street - Reading                  47.0   47.063830   9.025096
# Birmingham New Street - Stafford                190.0    7.184211   2.328286
# Birmingham New Street - Tamworth                227.0    7.603524   3.081717
# Birmingham New Street - Wolverhampton            32.0    1.875000   1.431219
# Birmingham New Street - York                     65.0   20.723077  10.863511
# Bristol Temple Meads - Cardiff Central           16.0    6.125000   1.627882
# Edinburgh Waverley - London Kings Cross          51.0   41.039216  16.770165
# Liverpool Lime Street - Birmingham New Street    14.0   31.142857   6.490907
# Liverpool Lime Street - Crewe                   193.0    8.098446   2.242034
# Liverpool Lime Street - Leeds                    96.0   12.135417   5.302670
# Liverpool Lime Street - London Euston          1097.0  103.280766  39.262377
# Liverpool Lime Street - London Paddington        27.0   99.962963  51.704398
# Liverpool Lime Street - London St Pancras        31.0  104.774194  30.331183
# Liverpool Lime Street - Manchester Piccadilly  3002.0    3.980680   2.541549
# Liverpool Lime Street - Sheffield               101.0    9.049505   3.017868
# London Euston - Birmingham New Street          4209.0   11.962224  15.244716
# London Euston - Manchester Piccadilly           712.0   85.679775  33.588077
# London Euston - Oxford                           16.0    2.562500   0.512348
# London Euston - York                             17.0   38.294118   5.335784
# London Kings Cross - Edinburgh Waverley         163.0   37.325153  14.727518
# London Kings Cross - Liverpool Lime Street      144.0   72.034722  26.749920
# London Kings Cross - York                      3922.0   46.709077  17.034755
# London Paddington - Liverpool Lime Street        44.0   55.772727  13.787193
# London Paddington - London Waterloo              68.0    5.044118   2.061979
# London Paddington - Manchester Piccadilly        30.0   93.933333  20.941517
# London Paddington - Oxford                      485.0   26.513402   9.652769
# London Paddington - Reading                    3873.0   16.877872   7.722981
# London St Pancras - Birmingham New Street      3471.0   15.231634  17.799538
# London St Pancras - Leicester                   337.0   21.821958   6.901371
# Birmingham New Street - Liverpool Lime Street   77.0
# Birmingham New Street - London Euston          109.0
# Birmingham New Street - London Kings Cross      78.0
# Birmingham New Street - London Paddington       78.0
# Birmingham New Street - London St Pancras      117.0
# Birmingham New Street - Manchester Piccadilly   38.0
# Birmingham New Street - Nuneaton                28.0
# Birmingham New Street - Reading                 63.0
# Birmingham New Street - Stafford                14.0
# Birmingham New Street - Tamworth                21.0
# Birmingham New Street - Wolverhampton            8.0
# Birmingham New Street - York                    65.0
# Bristol Temple Meads - Cardiff Central           9.0
# Edinburgh Waverley - London Kings Cross         96.0
# Liverpool Lime Street - Birmingham New Street   41.0
# Liverpool Lime Street - Crewe                   11.0
# Liverpool Lime Street - Leeds                   30.0
# Liverpool Lime Street - London Euston          235.0
# Liverpool Lime Street - London Paddington      238.0
# Liverpool Lime Street - London St Pancras      154.0
# Liverpool Lime Street - Manchester Piccadilly   20.0
# Liverpool Lime Street - Sheffield               19.0
# London Euston - Birmingham New Street          104.0
# London Euston - Manchester Piccadilly          216.0
# London Euston - Oxford                           3.0
# London Euston - York                            59.0
# London Kings Cross - Edinburgh Waverley         96.0
# London Kings Cross - Liverpool Lime Street     211.0
# London Kings Cross - York                      114.0
# London Paddington - Liverpool Lime Street      106.0
# London Paddington - London Waterloo             11.0
# London Paddington - Manchester Piccadilly      146.0
# London Paddington - Oxford                      63.0
# London Paddington - Reading                     54.0
# London St Pancras - Birmingham New Street      107.0
# London St Pancras - Leicester                   39.0
# London St Pancras - Wolverhampton               71.0
# Manchester Piccadilly - Leeds                   29.0
# Manchester Piccadilly - Liverpool Lime Street   19.0
# Manchester Piccadilly - London Euston          267.0
# Manchester Piccadilly - London Kings Cross     180.0
# Manchester Piccadilly - London Paddington      203.0
# Manchester Piccadilly - London St Pancras      135.0
# Manchester Piccadilly - Nottingham              17.0
# Manchester Piccadilly - Sheffield               11.0
# Manchester Piccadilly - Warrington               5.0
# Manchester Piccadilly - York                    21.0
# Oxford - Bristol Temple Meads                  102.0
# Reading - Birmingham New Street                 94.0
# Reading - Didcot                                13.0
# Reading - Liverpool Lime Street                242.0
# Reading - London Paddington                     25.0
# Reading - Oxford                                17.0
# Reading - Swindon                               59.0
# York - Birmingham New Street                    74.0
# York - Doncaster                                22.0
# York - Durham                                   15.0
# York - Edinburgh                                54.0
# York - Edinburgh Waverley                       35.0
# York - Leeds                                    10.0
# York - Liverpool Lime Street                    30.0
# York - Peterborough                             93.0
# York - Wakefield                                17.0

# %%
# show the value counts of refund request
df_railway['Refund Request'].value_counts()
# Out:
# Refund Request
# No     30535
# Yes     1118
# Name: count, dtype: int64

# %%
# count the number of rows per transaction id, then show the first 5 rows of transactions that had more than one row
transaction_counts = df_railway['Transaction ID'].value_counts()
transaction_counts[transaction_counts > 1]
# Out:
# Series([], Name: count, dtype: int64)

# %%
# write df_railway to a new csv file called railway_cleaned.csv in the data folder
df_railway.to_csv('../data/railway_cleaned.csv', index=False)
